# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
import matplotlib.pyplot as plt

# %%
np.random.seed(888)

#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227, 227,1), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096)) #input_shape=(225*225,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 57, 57, 96)        11712
#
#  activation (Activation)     (None, 57, 57, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 256)       614656
#
#  activation_1 (Activation)   (None, 29, 29, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 384)       885120
#
#  activation_2 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 384)       1327488
#
#  activation_3 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)       884992
#
#  activation_4 (Activation)   (None, 15, 15, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 91,716,241
# Trainable params: 91,716,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir="/notebooks/ultrasound/train"
validation_dir=train_dir

# %%
image_shape=(227,227)
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

batch_size_curr=64
train_data = keras.preprocessing.image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=image_shape,\
      subset='training',seed=12, validation_split=0.3,batch_size=batch_size_curr)
validation_data = keras.preprocessing.image_dataset_from_directory(\
      validation_dir,color_mode="grayscale",image_size=image_shape,\
      subset='validation',seed=12, validation_split=0.3,batch_size=batch_size_curr)
# Out:
# Found 8116 files belonging to 2 classes.
# Using 5682 files for training.
# Found 8116 files belonging to 2 classes.
# Using 2434 files for validation.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data,callbacks=[callback])
# Out:
# Epoch 1/100
# 89/89 [==============================] - 14s 117ms/step - loss: 10.4216 - binary_accuracy: 0.5773 - val_loss: 0.6823 - val_binary_accuracy: 0.5107
# Epoch 2/100
# 89/89 [==============================] - 10s 108ms/step - loss: 0.6367 - binary_accuracy: 0.6454 - val_loss: 0.6059 - val_binary_accuracy: 0.6598
# Epoch 3/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.5444 - binary_accuracy: 0.7288 - val_loss: 0.5094 - val_binary_accuracy: 0.7744
# Epoch 4/100
# 89/89 [==============================] - 9s 94ms/step - loss: 0.4305 - binary_accuracy: 0.7997 - val_loss: 0.3537 - val_binary_accuracy: 0.8324
# Epoch 5/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.4455 - binary_accuracy: 0.7981 - val_loss: 0.4678 - val_binary_accuracy: 0.7695
# Epoch 6/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.3934 - binary_accuracy: 0.8226 - val_loss: 0.4678 - val_binary_accuracy: 0.7966
# Epoch 7/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.3327 - binary_accuracy: 0.8545 - val_loss: 0.3274 - val_binary_accuracy: 0.8558
# Epoch 8/100
# 89/89 [==============================] - 10s 107ms/step - loss: 0.2803 - binary_accuracy: 0.8794 - val_loss: 0.2885 - val_binary_accuracy: 0.8718
# Epoch 9/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.2359 - binary_accuracy: 0.9021 - val_loss: 0.1773 - val_binary_accuracy: 0.9203
# Epoch 10/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.1713 - binary_accuracy: 0.9329 - val_loss: 0.1935 - val_binary_accuracy: 0.9187
# Epoch 11/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.1590 - binary_accuracy: 0.9365 - val_loss: 0.1428 - val_binary_accuracy: 0.9380
# Epoch 12/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.1379 - binary_accuracy: 0.9444 - val_loss: 0.1660 - val_binary_accuracy: 0.9273
# Epoch 13/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.1252 - binary_accuracy: 0.9521 - val_loss: 0.1168 - val_binary_accuracy: 0.9491
# Epoch 14/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.1120 - binary_accuracy: 0.9564 - val_loss: 0.0743 - val_binary_accuracy: 0.9655
# Epoch 15/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.1121 - binary_accuracy: 0.9565 - val_loss: 0.0927 - val_binary_accuracy: 0.9626
# Epoch 16/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0928 - binary_accuracy: 0.9671 - val_loss: 0.1178 - val_binary_accuracy: 0.9647
# Epoch 17/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.1027 - binary_accuracy: 0.9606 - val_loss: 0.1681 - val_binary_accuracy: 0.9355
# Epoch 18/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0899 - binary_accuracy: 0.9653 - val_loss: 0.0716 - val_binary_accuracy: 0.9741
# Epoch 19/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0710 - binary_accuracy: 0.9720 - val_loss: 0.1119 - val_binary_accuracy: 0.9589
# Epoch 20/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0900 - binary_accuracy: 0.9652 - val_loss: 0.0711 - val_binary_accuracy: 0.9704
# Epoch 21/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0577 - binary_accuracy: 0.9766 - val_loss: 0.0997 - val_binary_accuracy: 0.9795
# Epoch 22/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0573 - binary_accuracy: 0.9780 - val_loss: 0.0872 - val_binary_accuracy: 0.9655
# Epoch 23/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0685 - binary_accuracy: 0.9741 - val_loss: 0.0722 - val_binary_accuracy: 0.9745
# Epoch 24/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0662 - binary_accuracy: 0.9754 - val_loss: 0.0888 - val_binary_accuracy: 0.9795
# Epoch 25/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0768 - binary_accuracy: 0.9738 - val_loss: 0.1154 - val_binary_accuracy: 0.9552
# Epoch 26/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0568 - binary_accuracy: 0.9791 - val_loss: 0.0787 - val_binary_accuracy: 0.9795
# Epoch 27/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0750 - binary_accuracy: 0.9731 - val_loss: 0.0991 - val_binary_accuracy: 0.9634
# Epoch 28/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0559 - binary_accuracy: 0.9776 - val_loss: 0.0566 - val_binary_accuracy: 0.9778
# Epoch 29/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0618 - binary_accuracy: 0.9801 - val_loss: 0.0682 - val_binary_accuracy: 0.9766
# Epoch 30/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0651 - binary_accuracy: 0.9803 - val_loss: 0.0906 - val_binary_accuracy: 0.9659
# Epoch 31/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0444 - binary_accuracy: 0.9813 - val_loss: 0.0750 - val_binary_accuracy: 0.9758
# Epoch 32/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0388 - binary_accuracy: 0.9840 - val_loss: 0.1257 - val_binary_accuracy: 0.9778
# Epoch 33/100
# 89/89 [==============================] - 8s 91ms/step - loss: 0.0486 - binary_accuracy: 0.9824 - val_loss: 0.0858 - val_binary_accuracy: 0.9762
# Epoch 34/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0275 - binary_accuracy: 0.9873 - val_loss: 0.0580 - val_binary_accuracy: 0.9778
# Epoch 35/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0293 - binary_accuracy: 0.9898 - val_loss: 0.1312 - val_binary_accuracy: 0.9717
# Epoch 36/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0663 - binary_accuracy: 0.9787 - val_loss: 0.1059 - val_binary_accuracy: 0.9597
# Epoch 37/100
# 89/89 [==============================] - 8s 92ms/step - loss: 0.0441 - binary_accuracy: 0.9849 - val_loss: 0.0781 - val_binary_accuracy: 0.9795
# Epoch 38/100
# 89/89 [==============================] - 8s 90ms/step - loss: 0.0291 - binary_accuracy: 0.9917 - val_loss: 0.0832 - val_binary_accuracy: 0.9766

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()
