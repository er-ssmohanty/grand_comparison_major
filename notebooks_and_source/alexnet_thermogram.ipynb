# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
import matplotlib.pyplot as plt

# %%
np.random.seed(888)

#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227, 227,1), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096)) #input_shape=(225*225,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 57, 57, 96)        11712
#
#  activation (Activation)     (None, 57, 57, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 256)       614656
#
#  activation_1 (Activation)   (None, 29, 29, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 384)       885120
#
#  activation_2 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 384)       1327488
#
#  activation_3 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)       884992
#
#  activation_4 (Activation)   (None, 15, 15, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 91,716,241
# Trainable params: 91,716,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir="/notebooks/hnas_major/notebooks/thermograms/Imagens e Matrizes da Tese de Thiago Alves Elias da Silva/Desenvolvimento da Metodologia"
validation_dir=train_dir

# %%
image_shape=(227,227)
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

batch_size_curr=64
train_data = keras.preprocessing.image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=image_shape,\
      subset='training',seed=12, validation_split=0.3,batch_size=batch_size_curr)
validation_data = keras.preprocessing.image_dataset_from_directory(\
      validation_dir,color_mode="grayscale",image_size=image_shape,\
      subset='validation',seed=12, validation_split=0.3,batch_size=batch_size_curr)
# Out:
# Found 1282 files belonging to 2 classes.
# Using 898 files for training.
# Found 1282 files belonging to 2 classes.
# Using 384 files for validation.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data,callbacks=[callback])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 5s 140ms/step - loss: 33.1302 - binary_accuracy: 0.5757 - val_loss: 0.6648 - val_binary_accuracy: 0.4948
# Epoch 2/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.5512 - binary_accuracy: 0.7049 - val_loss: 0.6306 - val_binary_accuracy: 0.7839
# Epoch 3/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4720 - binary_accuracy: 0.8062 - val_loss: 0.4255 - val_binary_accuracy: 0.7865
# Epoch 4/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.4247 - binary_accuracy: 0.7873 - val_loss: 0.3546 - val_binary_accuracy: 0.8255
# Epoch 5/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3198 - binary_accuracy: 0.8664 - val_loss: 0.3301 - val_binary_accuracy: 0.8385
# Epoch 6/100
# 15/15 [==============================] - 2s 107ms/step - loss: 0.2919 - binary_accuracy: 0.8775 - val_loss: 0.3233 - val_binary_accuracy: 0.8646
# Epoch 7/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.2770 - binary_accuracy: 0.8742 - val_loss: 0.3400 - val_binary_accuracy: 0.8594
# Epoch 8/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.2221 - binary_accuracy: 0.8898 - val_loss: 0.4037 - val_binary_accuracy: 0.8802
# Epoch 9/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.1682 - binary_accuracy: 0.9287 - val_loss: 0.2455 - val_binary_accuracy: 0.8958
# Epoch 10/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.1221 - binary_accuracy: 0.9510 - val_loss: 0.2384 - val_binary_accuracy: 0.8906
# Epoch 11/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.1203 - binary_accuracy: 0.9421 - val_loss: 0.2464 - val_binary_accuracy: 0.9401
# Epoch 12/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.0598 - binary_accuracy: 0.9833 - val_loss: 0.2193 - val_binary_accuracy: 0.9505
# Epoch 13/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.0529 - binary_accuracy: 0.9811 - val_loss: 0.2917 - val_binary_accuracy: 0.9167
# Epoch 14/100
# 15/15 [==============================] - 2s 115ms/step - loss: 0.0449 - binary_accuracy: 0.9822 - val_loss: 0.2263 - val_binary_accuracy: 0.9505
# Epoch 15/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.0237 - binary_accuracy: 0.9944 - val_loss: 0.1747 - val_binary_accuracy: 0.9661
# Epoch 16/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.0139 - binary_accuracy: 0.9944 - val_loss: 0.1708 - val_binary_accuracy: 0.9688
# Epoch 17/100
# 15/15 [==============================] - 2s 111ms/step - loss: 0.0535 - binary_accuracy: 0.9844 - val_loss: 0.1372 - val_binary_accuracy: 0.9583
# Epoch 18/100
# 15/15 [==============================] - 2s 109ms/step - loss: 0.0625 - binary_accuracy: 0.9755 - val_loss: 0.2010 - val_binary_accuracy: 0.9505
# Epoch 19/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.1279 - binary_accuracy: 0.9588 - val_loss: 0.1227 - val_binary_accuracy: 0.9583
# Epoch 20/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.0825 - binary_accuracy: 0.9644 - val_loss: 0.1988 - val_binary_accuracy: 0.9583
# Epoch 21/100
# 15/15 [==============================] - 2s 115ms/step - loss: 0.0443 - binary_accuracy: 0.9822 - val_loss: 0.2320 - val_binary_accuracy: 0.9479
# Epoch 22/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.0287 - binary_accuracy: 0.9866 - val_loss: 0.2229 - val_binary_accuracy: 0.9583
# Epoch 23/100
# 15/15 [==============================] - 2s 113ms/step - loss: 0.0356 - binary_accuracy: 0.9911 - val_loss: 0.2636 - val_binary_accuracy: 0.9401
# Epoch 24/100
# 15/15 [==============================] - 2s 112ms/step - loss: 0.0192 - binary_accuracy: 0.9933 - val_loss: 0.2010 - val_binary_accuracy: 0.9609
# Epoch 25/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.0089 - binary_accuracy: 0.9978 - val_loss: 0.3015 - val_binary_accuracy: 0.9479
# Epoch 26/100
# 15/15 [==============================] - 2s 110ms/step - loss: 0.0023 - binary_accuracy: 1.0000 - val_loss: 0.2114 - val_binary_accuracy: 0.9714
# Epoch 27/100
# 15/15 [==============================] - 2s 113ms/step - loss: 4.8184e-04 - binary_accuracy: 1.0000 - val_loss: 0.2381 - val_binary_accuracy: 0.9714
# Epoch 28/100
# 15/15 [==============================] - 2s 110ms/step - loss: 2.5289e-04 - binary_accuracy: 1.0000 - val_loss: 0.2490 - val_binary_accuracy: 0.9714
# Epoch 29/100
# 15/15 [==============================] - 2s 112ms/step - loss: 6.9874e-05 - binary_accuracy: 1.0000 - val_loss: 0.2405 - val_binary_accuracy: 0.9740

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()
