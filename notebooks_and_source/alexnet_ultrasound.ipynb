# %%
from tensorflow import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.activations import leaky_relu 
from keras.preprocessing.image import ImageDataGenerator
from keras import Sequential
import matplotlib.pyplot as plt

# %%
np.random.seed(888)

#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(227, 227,1), kernel_size=(11,11), strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096)) #input_shape=(225*225,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 57, 57, 96)        11712
#
#  activation (Activation)     (None, 57, 57, 96)        0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 256)       614656
#
#  activation_1 (Activation)   (None, 29, 29, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 384)       885120
#
#  activation_2 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 384)       1327488
#
#  activation_3 (Activation)   (None, 15, 15, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)       884992
#
#  activation_4 (Activation)   (None, 15, 15, 256)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 4096)              67112960
#
#  activation_5 (Activation)   (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  activation_6 (Activation)   (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1000)              4097000
#
#  activation_7 (Activation)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_3 (Dense)             (None, 1)                 1001
#
#  activation_8 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 91,716,241
# Trainable params: 91,716,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir="/notebooks/ultrasound/train"
validation_dir=train_dir

# %%
image_shape=(227,227)
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

batch_size_curr=64
train_data = keras.preprocessing.image_dataset_from_directory(\
      train_dir,color_mode="grayscale",image_size=image_shape,\
      subset='training',seed=12, validation_split=0.3,batch_size=batch_size_curr)
validation_data = keras.preprocessing.image_dataset_from_directory(\
      validation_dir,color_mode="grayscale",image_size=image_shape,\
      subset='validation',seed=12, validation_split=0.3,batch_size=batch_size_curr)
# Out:
# Found 8116 files belonging to 2 classes.
# Using 5682 files for training.
# Found 8116 files belonging to 2 classes.
# Using 2434 files for validation.

# %%
model.compile(loss="BinaryCrossentropy", optimizer='Adam', metrics=["BinaryAccuracy"])

# %%
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(train_data,
            epochs=100,
            validation_data=validation_data,callbacks=[callback])
# Out:
# Epoch 1/100
# 89/89 [==============================] - 14s 100ms/step - loss: 33.9602 - binary_accuracy: 0.5366 - val_loss: 0.6017 - val_binary_accuracy: 0.6910
# Epoch 2/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.5328 - binary_accuracy: 0.7511 - val_loss: 0.5162 - val_binary_accuracy: 0.7157
# Epoch 3/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.4260 - binary_accuracy: 0.7973 - val_loss: 0.3897 - val_binary_accuracy: 0.8127
# Epoch 4/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.3359 - binary_accuracy: 0.8451 - val_loss: 0.2673 - val_binary_accuracy: 0.8833
# Epoch 5/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.3075 - binary_accuracy: 0.8728 - val_loss: 0.3641 - val_binary_accuracy: 0.8287
# Epoch 6/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.3245 - binary_accuracy: 0.8550 - val_loss: 0.2253 - val_binary_accuracy: 0.8981
# Epoch 7/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.2225 - binary_accuracy: 0.9090 - val_loss: 0.1690 - val_binary_accuracy: 0.9260
# Epoch 8/100
# 89/89 [==============================] - 7s 78ms/step - loss: 0.1777 - binary_accuracy: 0.9285 - val_loss: 0.2044 - val_binary_accuracy: 0.9158
# Epoch 9/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.1816 - binary_accuracy: 0.9259 - val_loss: 0.1766 - val_binary_accuracy: 0.9314
# Epoch 10/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.1655 - binary_accuracy: 0.9314 - val_loss: 0.1042 - val_binary_accuracy: 0.9544
# Epoch 11/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.1170 - binary_accuracy: 0.9527 - val_loss: 0.0905 - val_binary_accuracy: 0.9601
# Epoch 12/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0861 - binary_accuracy: 0.9646 - val_loss: 0.1173 - val_binary_accuracy: 0.9556
# Epoch 13/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0965 - binary_accuracy: 0.9653 - val_loss: 0.0944 - val_binary_accuracy: 0.9651
# Epoch 14/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0602 - binary_accuracy: 0.9782 - val_loss: 0.0941 - val_binary_accuracy: 0.9667
# Epoch 15/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0884 - binary_accuracy: 0.9662 - val_loss: 0.0836 - val_binary_accuracy: 0.9651
# Epoch 16/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0570 - binary_accuracy: 0.9794 - val_loss: 0.0996 - val_binary_accuracy: 0.9634
# Epoch 17/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0662 - binary_accuracy: 0.9755 - val_loss: 0.0995 - val_binary_accuracy: 0.9610
# Epoch 18/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.1079 - binary_accuracy: 0.9632 - val_loss: 0.0899 - val_binary_accuracy: 0.9651
# Epoch 19/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0674 - binary_accuracy: 0.9754 - val_loss: 0.2216 - val_binary_accuracy: 0.9211
# Epoch 20/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0827 - binary_accuracy: 0.9690 - val_loss: 0.1065 - val_binary_accuracy: 0.9610
# Epoch 21/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0936 - binary_accuracy: 0.9722 - val_loss: 0.1894 - val_binary_accuracy: 0.9318
# Epoch 22/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.1236 - binary_accuracy: 0.9588 - val_loss: 0.1275 - val_binary_accuracy: 0.9560
# Epoch 23/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0598 - binary_accuracy: 0.9771 - val_loss: 0.0503 - val_binary_accuracy: 0.9827
# Epoch 24/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0508 - binary_accuracy: 0.9805 - val_loss: 0.0656 - val_binary_accuracy: 0.9803
# Epoch 25/100
# 89/89 [==============================] - 7s 75ms/step - loss: 0.0287 - binary_accuracy: 0.9893 - val_loss: 0.1934 - val_binary_accuracy: 0.9548
# Epoch 26/100
# 89/89 [==============================] - 7s 74ms/step - loss: 0.0890 - binary_accuracy: 0.9762 - val_loss: 0.1734 - val_binary_accuracy: 0.9626
# Epoch 27/100
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0846 - binary_accuracy: 0.9745 - val_loss: 0.1349 - val_binary_accuracy: 0.9458
# Epoch 28/100
# 89/89 [==============================] - 7s 77ms/step - loss: 0.0611 - binary_accuracy: 0.9773 - val_loss: 0.0954 - val_binary_accuracy: 0.9708
# Epoch 29/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0436 - binary_accuracy: 0.9838 - val_loss: 0.0786 - val_binary_accuracy: 0.9766
# Epoch 30/100
# 89/89 [==============================] - 7s 78ms/step - loss: 0.0585 - binary_accuracy: 0.9787 - val_loss: 0.1373 - val_binary_accuracy: 0.9651
# Epoch 31/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.1913 - binary_accuracy: 0.9542 - val_loss: 0.1567 - val_binary_accuracy: 0.9445
# Epoch 32/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.1462 - binary_accuracy: 0.9516 - val_loss: 0.1554 - val_binary_accuracy: 0.9671
# Epoch 33/100
# 89/89 [==============================] - 7s 76ms/step - loss: 0.0645 - binary_accuracy: 0.9766 - val_loss: 0.2233 - val_binary_accuracy: 0.9412

# %%
epochs_run=len(history.epoch)

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs_run)
plt.style.use('ggplot')
plt.figure(figsize=(18, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.figure(figsize=(18, 5))
plt.subplot(1,2,1)
plt.plot(epochs_range, np.log(loss), label='Training Loss')
plt.plot(epochs_range, np.log(val_loss), label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Logarithm of Training and Validation Loss')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

plt.show()
